# %%
import cv2
import matplotlib.pyplot as plt

# %% [markdown]
# ## **Detection**

# %%
date_img = cv2.imread("162004.jpg", cv2.IMREAD_COLOR_RGB)
plt.imshow(date_img)

# %%
date_img = cv2.rectangle(date_img, pt1=(2,67), pt2=(137,194), color=(0, 255, 0), thickness=4)
date_img = cv2.rectangle(date_img, pt1=(252,6), pt2=(378,210), color=(0, 255, 0), thickness=4)
date_img = cv2.rectangle(date_img, pt1=(482,61), pt2=(953,252), color=(0, 255, 0), thickness=4)
plt.imshow(date_img)

# %% [markdown]
# ![image.png](attachment:image.png)
