# %%
from day_month_data_pipeline import DayMonth_data_pipeline

data_pipeline = DayMonth_data_pipeline(data_dir="dataset/day_month")

# %%
img_dataframe = data_pipeline.create_image_dataframe()
img_dataframe
# Out:
#                             image_path  label
# 0        dataset\day_month\0\100_0.jpg      0
# 1     dataset\day_month\0\100_0_up.jpg      0
# 2        dataset\day_month\0\101_0.jpg      0
# 3     dataset\day_month\0\101_0_up.jpg      0
# 4        dataset\day_month\0\102_0.jpg      0
# ...                                ...    ...
# 3560   dataset\day_month\9\98_9_up.jpg      9
# 3561      dataset\day_month\9\99_9.jpg      9
# 3562   dataset\day_month\9\99_9_up.jpg      9
# 3563       dataset\day_month\9\9_9.jpg      9
# 3564    dataset\day_month\9\9_9_up.jpg      9
#
# [3565 rows x 2 columns]

# %%
img_data_count = img_dataframe["label"].value_counts()
print(img_data_count)
# Out:
# label
# 9     269
# 5     267
# 6     265
# 3     263
# 4     261
# 8     260
# 7     259
# 2     257
# 1     256
# 0     256
# 21     53
# 24     49
# 13     48
# 10     47
# 12     46
# 16     46
# 25     46
# 29     46
# 23     45
# 22     45
# 20     43
# 11     43
# 19     43
# 26     42
# 31     42
# 15     41
# 14     40
# 30     40
# 28     38
# 17     38
# 27     37
# 18     34
# Name: count, dtype: int64

# %%
img_data_count_less_than_200 = img_data_count[img_data_count<200]
img_data_count_less_than_200
# Out:
# label
# 21    53
# 24    49
# 13    48
# 10    47
# 12    46
# 16    46
# 25    46
# 29    46
# 23    45
# 22    45
# 20    43
# 11    43
# 19    43
# 26    42
# 31    42
# 15    41
# 14    40
# 30    40
# 28    38
# 17    38
# 27    37
# 18    34
# Name: count, dtype: int64
