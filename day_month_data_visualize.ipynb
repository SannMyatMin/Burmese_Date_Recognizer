# %% [markdown]
# # **Day and Month Data Visualize**

# %%
from day_month_data_pipeline import DayMonth_data_pipeline

data_pipeline = DayMonth_data_pipeline(data_dir="dataset/day_month")

# %% [markdown]
# ## **Dataframe**

# %%
img_dataframe = data_pipeline.create_image_dataframe()
img_dataframe
# Out:
#                             image_path  label
# 0        dataset\day_month\0\100_0.jpg      0
# 1     dataset\day_month\0\100_0_up.jpg      0
# 2        dataset\day_month\0\101_0.jpg      0
# 3     dataset\day_month\0\101_0_up.jpg      0
# 4        dataset\day_month\0\102_0.jpg      0
# ...                                ...    ...
# 4030   dataset\day_month\9\98_9_up.jpg      9
# 4031      dataset\day_month\9\99_9.jpg      9
# 4032   dataset\day_month\9\99_9_up.jpg      9
# 4033       dataset\day_month\9\9_9.jpg      9
# 4034    dataset\day_month\9\9_9_up.jpg      9
#
# [4035 rows x 2 columns]

# %%
img_data_count = img_dataframe["label"].value_counts()
print(img_data_count)
# Out:
# label
# 9     287
# 5     283
# 6     281
# 3     279
# 7     275
# 4     275
# 8     269
# 2     268
# 1     263
# 0     263
# 21     70
# 13     67
# 24     66
# 12     63
# 23     62
# 10     61
# 16     61
# 25     61
# 31     61
# 20     61
# 19     61
# 11     59
# 22     59
# 29     59
# 30     57
# 26     56
# 15     56
# 14     54
# 28     52
# 17     50
# 18     49
# 27     47
# Name: count, dtype: int64

# %%
img_data_count_less_than_200 = img_data_count[img_data_count<200]
img_data_count_less_than_200
# Out:
# label
# 21    70
# 13    67
# 24    66
# 12    63
# 23    62
# 10    61
# 16    61
# 25    61
# 31    61
# 20    61
# 19    61
# 11    59
# 22    59
# 29    59
# 30    57
# 26    56
# 15    56
# 14    54
# 28    52
# 17    50
# 18    49
# 27    47
# Name: count, dtype: int64
